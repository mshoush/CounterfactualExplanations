# %%
# train the BLack-box model: Classifire
# %load_ext autoreload
# %autoreload 2

import os

#!export PYTORCH_CUDA_ALLOC_CONF=max_split_size_mb=128
import torch
torch.cuda.empty_cache()
# Manually set SLURM environment variables if they are not set
if "SLURM_NTASKS" not in os.environ:
    os.environ["SLURM_NTASKS"] = "2"
if "SLURM_NTASKS_PER_NODE" not in os.environ:
    os.environ["SLURM_NTASKS_PER_NODE"] = "2"

    
print("SLURM_NTASKS:", os.environ.get("SLURM_NTASKS"))
print("SLURM_NTASKS_PER_NODE:", os.environ.get("SLURM_NTASKS_PER_NODE"))

    
print("Starting classification...")
# !./NNProject/bin/python ./counterfactual-search/tools/train.py -c ./counterfactual-search/configs/classification/clf_mahmoud.yaml
print("Done with classification...")


# print("Starting Counterfactual....")
# !./NNProject/bin/python ./counterfactual-search/tools/train.py -c ./counterfactual-search/configs/counterfactual/cf_inpainting_mahmoud.yaml
# print("Done with CounterFactual")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# SLURM_NTASKS: 2
# SLURM_NTASKS_PER_NODE: 2
# Starting classification...
# ^C
# Traceback (most recent call last):
#   File "/gpfs/space/home/shoush/nn_project/project/./counterfactual-search/tools/train.py", line 9, in <module>
#     from src.models import build_model
#   File "/gpfs/space/home/shoush/nn_project/project/counterfactual-search/src/models/__init__.py", line 1, in <module>
#     from src.models.cgan import build_gan
#   File "/gpfs/space/home/shoush/nn_project/project/counterfactual-search/src/models/cgan/__init__.py", line 1, in <module>
#     from .counterfactual_cgan import CounterfactualCGAN
#   File "/gpfs/space/home/shoush/nn_project/project/counterfactual-search/src/models/cgan/counterfactual_cgan.py", line 4, in <module>
#     import lightning as L
# ...

# %%
# Train the Counterfactual part and use the trained classifire
# %load_ext autoreload
# %autoreload 2
# %cd /gpfs/space/home/shoush/nn_project/project

#%matplotlib inline
import os

#!export PYTORCH_CUDA_ALLOC_CONF=max_split_size_mb=128
import torch
torch.cuda.empty_cache()
# Manually set SLURM environment variables if they are not set
if "SLURM_NTASKS" not in os.environ:
    os.environ["SLURM_NTASKS"] = "2"
if "SLURM_NTASKS_PER_NODE" not in os.environ:
    os.environ["SLURM_NTASKS_PER_NODE"] = "2"

    
print("SLURM_NTASKS:", os.environ.get("SLURM_NTASKS"))
print("SLURM_NTASKS_PER_NODE:", os.environ.get("SLURM_NTASKS_PER_NODE"))

    
print("Starting Counterfactual....")
# !./NNProject/bin/python ./counterfactual-search/tools/train.py -c ./counterfactual-search/configs/counterfactual/fourClasses_cgan_mahmoud_v2.yaml # COIN Four Classes
# !./NNProject/bin/python ./counterfactual-search/tools/train.py -c ./counterfactual-search/configs/counterfactual/fourClasses_coin_mahmoud_v2.yaml # COIN Four Classes
# !./NNProject/bin/python ./counterfactual-search/tools/train.py -c ./counterfactual-search/configs/counterfactual/twcClasses_coin_mahmoud_v2.yaml # COIN Two Classes
#!./NNProject/bin/python ./counterfactual-search/tools/train.py -c ./counterfactual-search/configs/counterfactual/twcClasses_cgan_mahmoud_v2.yaml # CGAN Two Classes
# !./NNProject/bin/python ./counterfactual-search/tools/train.py -c ./counterfactual-search/configs/counterfactual/twcClasses_cgan_mahmoud.yaml
# !./NNProject/bin/python ./counterfactual-search/tools/train.py -c ./counterfactual-search/configs/counterfactual/cf_mahmoud_counterfactual_inpainting_v2.yaml
# !./NNProject/bin/python ./counterfactual-search/tools/train.py -c ./counterfactual-search/configs/counterfactual/cf_cGAN_mahmoud.yaml
#!./NNProject/bin/python ./counterfactual-search/tools/train.py -c ./counterfactual-search/configs/counterfactual/cf_mahmoud_counterfactual_inpainting_v1.yaml
print("Done with CounterFactual")


# print("Starting Counterfactual....")
# !./NNProject/bin/python ./counterfactual-search/tools/train.py -c ./counterfactual-search/configs/counterfactual/cf_inpainting_mahmoud.yaml
# print("Done with CounterFactual")
# Out:
# /gpfs/space/home/shoush/nn_project/project/NNProject/lib/python3.9/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# /gpfs/space/home/shoush/nn_project/project
# SLURM_NTASKS: 2
# SLURM_NTASKS_PER_NODE: 2
# Starting Counterfactual....
# Here....
#
# opt: Namespace(config_path='./counterfactual-search/configs/counterfactual/fourClasses_cgan_mahmoud_v2.yaml', continue_path=None)
#
#
# args: Namespace(config_path='./counterfactual-search/configs/counterfactual/fourClasses_cgan_mahmoud_v2.yaml', continue_path=None)
#
# Using SNConv in generator: True
# Generator in channels [1024, 1536, 768, 384, 192]
# Generator out channels [1024, 512, 256, 128, 64]
# Using SNConv in generator: True
# Using perturbation fuse scheme: skip_add_tanh
# ...

# %%
# !pwd
# Out:
# /gpfs/space/home/shoush/nn_project/project

# %%
# Evaluate the counterfactual
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload
# %cd /gpfs/space/home/shoush/nn_project/project

import os

#!export PYTORCH_CUDA_ALLOC_CONF=max_split_size_mb=128
import torch
torch.cuda.empty_cache()
# Manually set SLURM environment variables if they are not set
if "SLURM_NTASKS" not in os.environ:
    os.environ["SLURM_NTASKS"] = "2"
if "SLURM_NTASKS_PER_NODE" not in os.environ:
    os.environ["SLURM_NTASKS_PER_NODE"] = "2"

    
print("SLURM_NTASKS:", os.environ.get("SLURM_NTASKS"))
print("SLURM_NTASKS_PER_NODE:", os.environ.get("SLURM_NTASKS_PER_NODE"))

    
print("Starting eval_counterfactual....")
#!./NNProject/bin/python ./counterfactual-search/tools/eval_counterfactual.py -cp './training_logs/paper_experiments_reproduce/cf_covid/counterfactual_lungs_cgan-May-29-2024_04+52PM-0000000-mahmoud_trial/'  -cft 0.25 -pcf
# !./NNProject/bin/python ./counterfactual-search/tools/eval_counterfactual.py -cp \
"training_logs/paper_experiments_reproduce/fourClasses_cgan_cf_covid_clf-explain-lungs_v6/counterfactual_lungs_cgan-June-07-2024_11+15PM-0000000-mahmoud_trial_FourClasses_cgan/" -cft 0.25 -pcf
# "training_logs/paper_experiments_reproduce/fourClasses_coin_cf_covid_clf-explain-lungs_v6/inpainting_counterfactual_cgan-June-07-2024_08+21PM-0000000-mahmoud_trial_FourClasses_coin/" -cft 0.25 -pcf
# "training_logs/paper_experiments_reproduce/fourClasses_coin_cf_covid_clf-explain-lungs_v6/inpainting_counterfactual_cgan-June-07-2024_07+00PM-0000000-mahmoud_trial_FourClasses_coin/" -cft 0.25 -pcf 
# "training_logs/paper_experiments_reproduce/TwoClasses_coin_cf_covid_clf-explain-lungs_v6/inpainting_counterfactual_cgan-June-07-2024_05+30PM-0000000-mahmoud_trial_TwoClasses_coin/" -cft 0.25 -pcf 
# "training_logs/paper_experiments_reproduce/TwoClasses_cf_covid_clf-explain-lungs_v6/counterfactual_lungs_cgan-June-07-2024_02+59PM-0000000-mahmoud_trial_clf-explain-lungs_TwoClass_v1/" -cft 0.25 -pcf # Two Classes CGAN
# "training_logs/paper_experiments_reproduce/cf_covid_counterfactual_inpainting_TwoClasses_v3/inpainting_counterfactual_cgan-June-07-2024_12+23AM-0000000-mahmoud_trial_counterfactual_inpainting_TwoClasses_v3" -cft 0.25 -pcf
# "training_logs/paper_experiments_reproduce/cf_covid_counterfactual_inpainting_TwoClasses_v1/inpainting_counterfactual_cgan-June-05-2024_09+04PM-0000000-mahmoud_trial_counterfactual_inpainting_TwoClasses_v1/" -cft 0.25 -pcf
# "training_logs/paper_experiments_reproduce/cf_covid_clf-explain-lungs_v4/counterfactual_lungs_cgan-June-05-2024_06+59PM-0000000-mahmoud_trial_clf-explain-lungs_TwoClass_v1/" -cft 0.25 -pcf
# "training_logs/paper_experiments_reproduce/cf_covid_counterfactual_inpainting_v2/inpainting_counterfactual_cgan-June-05-2024_09+16AM-0000000-mahmoud_trial_counterfactual_inpainting_v2" -cft 0.25 -pcf
# "/gpfs/space/home/shoush/nn_project/project/training_logs/paper_experiments_reproduce/cf_covid_clf-explain-lungs_v4/counterfactual_lungs_cgan-June-03-2024_10+26PM-0000000-mahmoud_trial_clf-explain-lungs_v4/" -cft 0.25 -pcf
#"/gpfs/space/home/shoush/nn_project/project/training_logs/paper_experiments_reproduce/cf_covid_counterfactual_inpainting_v1/inpainting_counterfactual_cgan-June-02-2024_12+28PM-0000000-mahmoud_trial_counterfactual_inpainting_v1/" -cft 0.25 -pcf


# training_logs/paper_experiments_reproduce/cf_covid_clf-explain-lungs_v2/counterfactual_lungs_cgan-May-30-2024_09+34AM-0000000-mahmoud_trial_clf-explain-lungs/" -cft 0.25 -pcf



#training_logs/paper_experiments_reproduce/cf_covid_clf-explain-lungs/counterfactual_lungs_cgan-May-29-2024_09+55PM-0000000-mahmoud_trial_clf-explain-lungs/" -cft 0.25 -pcf


# './training_logs/paper_experiments_reproduce/cf_covid_clf-explain-lungs/cf_covid_clf-explain-lungs/counterfactual_lungs_cgan-May-29-2024_09+55PM-0000000-mahmoud_trial_clf-explain-lungs/'  -cft 0.25 -pcf
# './training_logs/paper_experiments_reproduce/cf_covid_clf-explain-lungs/counterfactual_lungs_cgan-May-29-2024_09+55PM-0000000-mahmoud_trial_clf-explain-lungs/checkpoints/checkpoint_10.pth'

# './training_logs/paper_experiments_reproduce/synth_cf_explanations_vs_cf_inpainting/counterfactual_lungs_cgan-May-29-2024_01+51PM-0000000-tsm_synth-large_r18_bs16_arch4_fp32-fr_nearest_sc-1234_fix-prepr_df-fuse_cyclic_tv005_inpainting_v2/' -cft 0.25 -pcf

print("Done with eval_counterfactual")


# print("Starting Counterfactual....")
# !./NNProject/bin/python ./counterfactual-search/tools/train.py -c ./counterfactual-search/configs/counterfactual/cf_inpainting_mahmoud.yaml
# print("Done with CounterFactual")
# Out:
# /gpfs/space/home/shoush/nn_project/project/NNProject/lib/python3.9/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# /gpfs/space/home/shoush/nn_project/project
# SLURM_NTASKS: 2
# SLURM_NTASKS_PER_NODE: 2
# Starting eval_counterfactual....
# Using SNConv in generator: True
# Generator in channels [1024, 1536, 768, 384, 192]
# Generator out channels [1024, 512, 256, 128, 64]
# Using SNConv in generator: True
# Using perturbation fuse scheme: skip_add_tanh
# /gpfs/space/home/shoush/nn_project/project/NNProject/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# ...
